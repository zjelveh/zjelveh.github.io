# %% [markdown]
# # INST414 — Lab 8: Random Forest, Gradient Boosting, and AUC
#
# **How this notebook works:**
# - Everything **before** the **Lab Tasks** section is your **pre-lab** work to complete at home.
# - In lab, you'll complete the **Lab Tasks** section.
#
# In this lab you will:
# - fit **logistic regression**, **random forest**, and **gradient boosting** on the same prediction problem,
# - compare the models using **AUC**, **calibration**, and **precision**,
# - and think about how **ranking** and **calibration** are related but different.
#
# The main comparison in this notebook is:
# - Which model ranks cases best?
# - Which model gives the best-looking probabilities?

# %% [markdown]
# **Before you start:** Click **File -> Save a copy in Drive** so you have your own version of this notebook. If you skip this step, your work will not be saved.
#
# **Turn off AI assistance:** Go to **Settings -> AI Assistance** and uncheck everything. AI-generated code is not allowed on assignments in this course.

# %% [markdown]
# # Part 1 — Load modules and helper functions

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

pd.options.display.max_columns = None

from sklearn.calibration import calibration_curve
from sklearn.metrics import roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
def calibration_plot(y_true, y_prob, n_bins=10):
    """Plot average predicted probability against actual outcome rate using quantile bins."""
    prob_true, prob_pred = calibration_curve(y_true, y_prob, n_bins=n_bins, strategy='quantile')

    plt.figure(figsize=(6, 4))
    plt.plot(prob_pred, prob_true, marker='o')
    plt.plot([0, 1], [0, 1], linestyle='--')
    plt.xlabel('Average predicted probability')
    plt.ylabel('Actual outcome rate')
    plt.title('Calibration plot')
    plt.show()

# %%
def create_yhat(y_prob, threshold=0.5):
    return np.where(y_prob >= threshold, 1, 0)

# %% [markdown]
# ## Calibration vs AUC
#
# These are different ways of evaluating models.
#
# - **Calibration** asks whether predicted probabilities match actual rates.
# - **AUC** asks whether the model tends to assign higher scores to positive cases than negative cases.
#
# So a model can:
# - rank cases well but still be poorly calibrated, or
# - look fairly well calibrated without having the best ranking performance.

# %% [markdown]
# # Part 2 — Load data

# %%
pred_universe = pd.read_csv('https://www.dropbox.com/s/ckhwdenrp6w7aef/universe_lab8.csv?dl=1')
pred_universe.shape

# %%
pred_universe.head()

# %%
arrest_events = pd.read_csv('https://www.dropbox.com/scl/fi/41q9nvyrtf0hsfs2si1a1/arrest_events_lab8.csv?rlkey=9scrcgr65f3hgo26punp4qcso&dl=1')
arrest_events.shape

# %%
arrest_events.head()

# %% [markdown]
# ### Meaning of values in `outcome_at_init`
# - `ROR` = release on recognizance
# - `HDOB` = held on bail
# - `HWOB` = held without bail
#
# The outcome variable in `pred_universe` is `fta`, which is an indicator for failure to appear.

# %% [markdown]
# # Part 3 — Pre-lab: Feature engineering

# %% [markdown]
# ## Feature 1 — One-hot encode outcome at initialization
# We will one-hot encode `outcome_at_init` so we can use those categories as predictors.

# %%
pred_universe = pd.get_dummies(data=pred_universe, columns=['outcome_at_init'])

# %% [markdown]
# ## Feature 2 — Charge-degree features
# We next one-hot encode `charge_degree` in `arrest_events`. Since arrests can have multiple charges, we will sum within `arrest_id` after creating the dummy variables.

# %%
arrest_events = pd.get_dummies(data=arrest_events, columns=['charge_degree'])

# %%
charge_degrees = arrest_events.groupby(['arrest_id'])[
    ['charge_degree_felony', 'charge_degree_misdemeanor']
].sum().reset_index()

pred_universe = pred_universe.merge(charge_degrees, on=['arrest_id'])
pred_universe.shape

# %% [markdown]
# ## Feature 3 — Offense-category features
# We do the same thing for `offense_category`: one-hot encode, then sum within `arrest_id`.

# %%
arrest_events = pd.get_dummies(data=arrest_events, columns=['offense_category'])

# %%
offense_cat = arrest_events.groupby(['arrest_id'])[[
    'offense_category_drug',
    'offense_category_other',
    'offense_category_property',
    'offense_category_violent'
]].sum().reset_index()

pred_universe = pred_universe.merge(offense_cat, on=['arrest_id'])
pred_universe.shape

# %% [markdown]
# ## Final feature list
# We will use the same feature style as the previous lab so that the main new ideas are the models and the evaluation metrics.

# %%
features = [
    'age_at_arrest',
    'outcome_at_init_HDOB',
    'outcome_at_init_HWOB',
    'outcome_at_init_ROR',
    'charge_degree_felony',
    'charge_degree_misdemeanor',
    'offense_category_drug',
    'offense_category_other',
    'offense_category_property',
    'offense_category_violent'
]

features

# %% [markdown]
# # Part 4 — Train/test split
#
# We split the data into a **training set** and a **test set**.
#
# - The training set is used to fit models and run cross-validation.
# - The test set is used only for final out-of-sample evaluation.

# %%
train, test = train_test_split(
    pred_universe,
    test_size=0.5,
    shuffle=True,
    stratify=pred_universe['fta'],
    random_state=414
)

train.shape, test.shape

# %%
train['fta'].mean(), test['fta'].mean()

# %% [markdown]
# # Part 5 — Logistic regression baseline

# %% [markdown]
# We keep a simple logistic-regression baseline so we can compare the new tree-based ensemble models to a model that is directly trained to estimate probabilities.
#
# For logistic regression, we will:
# - fit the model on the training set,
# - predict probabilities on the test set,
# - compute AUC,
# - compute precision manually at threshold `0.5`,
# - and look at the calibration plot.

# %%
lr_model = LogisticRegression(max_iter=1000)
lr_model = lr_model.fit(train[features], train['fta'])

test['pred_lr'] = lr_model.predict_proba(test[features])[:, 1]

# %%
roc_auc_score(test['fta'], test['pred_lr'])

# %%
test['yhat_lr'] = create_yhat(test['pred_lr'], threshold=0.5)
(test.loc[test['yhat_lr'] == 1, 'fta']).mean()

# %%
calibration_plot(test['fta'], test['pred_lr'])

# %% [markdown]
# # Part 6 — Pre-lab: Random forest

# %% [markdown]
# We will tune **two** random-forest hyperparameters in the pre-lab:
#
# - `n_estimators`
# - `max_depth`
#
# We use **AUC** as the cross-validation score.
#
# After tuning, make sure you understand each of these steps:
# - look at the best hyperparameters,
# - predict probabilities for the test set,
# - compute test-set AUC,
# - create `yhat` using threshold `0.5`,
# - compute precision manually,
# - and look at the calibration plot.

# %%
param_grid_rf = {
    'n_estimators': [100, 300],
    'max_depth': [3, 5, None]
}

param_grid_rf

# %%
rf_gs = GridSearchCV(
    estimator=RandomForestClassifier(random_state=414),
    param_grid=param_grid_rf,
    cv=5,
    scoring='roc_auc'
)

# %%
rf_gs = rf_gs.fit(train[features], train['fta'])
rf_gs.best_params_

# %%
test['pred_rf'] = rf_gs.predict_proba(test[features])[:, 1]

roc_auc_score(test['fta'], test['pred_rf'])

# %%
test['yhat_rf'] = create_yhat(test['pred_rf'], threshold=0.5)
(test.loc[test['yhat_rf'] == 1, 'fta']).mean()

# %%
calibration_plot(test['fta'], test['pred_rf'])

# %% [markdown]
# # Part 7 — Pre-lab: Gradient boosting

# %% [markdown]
# We will tune **two** gradient-boosting hyperparameters in the pre-lab:
#
# - `n_estimators`
# - `learning_rate`
#
# Unlike random forest, gradient boosting builds trees **sequentially**, and with log loss it is trying to learn probabilities.
#
# After tuning, make sure you understand each of these steps:
# - look at the best hyperparameters,
# - predict probabilities for the test set,
# - compute test-set AUC,
# - create `yhat` using threshold `0.5`,
# - compute precision manually,
# - and look at the calibration plot.

# %%
param_grid_gb = {
    'n_estimators': [100, 300],
    'learning_rate': [0.05, 0.1]
}

param_grid_gb

# %%
gb_gs = GridSearchCV(
    estimator=GradientBoostingClassifier(random_state=414),
    param_grid=param_grid_gb,
    cv=5,
    scoring='roc_auc'
)

# %%
gb_gs = gb_gs.fit(train[features], train['fta'])
gb_gs.best_params_

# %%
test['pred_gb'] = gb_gs.predict_proba(test[features])[:, 1]

roc_auc_score(test['fta'], test['pred_gb'])

# %%
test['yhat_gb'] = create_yhat(test['pred_gb'], threshold=0.5)
(test.loc[test['yhat_gb'] == 1, 'fta']).mean()

# %%
calibration_plot(test['fta'], test['pred_gb'])

# %% [markdown]
# # Part 8 — Pre-lab comparison
#
# Below, we create a small table comparing the three pre-lab models.
#
# This table is meant to help you start thinking about two different questions:
# - Which model has the best **ranking** performance?
# - Which model appears to give the best **probabilities**?

# %%
pd.DataFrame({
    'model': ['Logistic Regression', 'Random Forest', 'Gradient Boosting'],
    'auc': [
        roc_auc_score(test['fta'], test['pred_lr']),
        roc_auc_score(test['fta'], test['pred_rf']),
        roc_auc_score(test['fta'], test['pred_gb'])
    ],
    'precision_at_0.5': [
        (test.loc[test['yhat_lr'] == 1, 'fta']).mean(),
        (test.loc[test['yhat_rf'] == 1, 'fta']).mean(),
        (test.loc[test['yhat_gb'] == 1, 'fta']).mean()
    ]
})

# %% [markdown]
# # Lab Tasks
#
# Complete the following tasks. Put your code in the blank cells underneath each prompt.
#
# Important:
# - When a task asks for **precision**, compute it manually from `yhat`.
# - Use threshold `0.5` unless the prompt says otherwise.
# - When asked to compare models, refer to both the **AUC values** and the **calibration plots**.

# %% [markdown]
# ## Task 1 — Extend random-forest tuning
#
# Add **one more** parameter to the random-forest grid.
#
# Use the blank code cells below to do the following in order:
# - create the new parameter grid,
# - rerun `GridSearchCV`,
# - show the new best hyperparameters,
# - predict probabilities for the test set,
# - compute test-set AUC,
# - create `yhat_rf_lab` using threshold `0.5`,
# - compute precision manually,
# - and plot the calibration curve.

# %% [markdown]
# ## Task 2 — Extend gradient-boosting tuning
#
# Add **two more** parameters to the gradient-boosting grid.
#
# Use the blank code cells below to do the following in order:
# - create the new parameter grid,
# - rerun `GridSearchCV`,
# - show the new best hyperparameters,
# - predict probabilities for the test set,
# - compute test-set AUC,
# - create `yhat_gb_lab` using threshold `0.5`,
# - compute precision manually,
# - and plot the calibration curve.

# %% [markdown]
# ## Task 3 — Compare models
#
# Create an updated comparison table for:
#
# - logistic regression
# - random forest
# - gradient boosting
#
# Include these columns:
# - `model`
# - `auc`
# - `precision_at_0.5` (computed manually from `yhat`)
#
# Use the tuned random-forest and gradient-boosting models from Tasks 1 and 2.

# %% [markdown]
# ## Task 4 — Compare calibration
#
# Look at the calibration plots for the three models.
#
# In 3 to 4 sentences, answer both questions:
# - Which model looks best calibrated?
# - Is that the same model with the highest AUC?
#
# Be specific and refer to what you see in the plots.

# %% [markdown]
# ## Task 5 — Compare and contrast
#
# In 4 to 6 sentences, answer all of the following:
# - How is random forest different from gradient boosting?
# - Which model seems best for ranking?
# - Which model seems best for probability estimation?
# - What do these results suggest about AUC versus calibration?
#
# Your answer should mention both the numerical results and the calibration plots.
