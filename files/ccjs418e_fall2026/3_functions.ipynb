# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/zjelveh/zjelveh.github.io/blob/master/files/ccjs418e_fall2026/3_functions.ipynb)
#
# **Save your own copy:**
# 1. Click File → Save a copy in Drive
# 2. Rename it with your name: `Functions_YourName`
# 3. Work in your copy
#
# ---
#
# # 3. Functions - Reusing an Analysis
# ## CCJS 418E: Coding for Criminology
#
# Today's goals:
# - Define and call a function
# - Understand parameters and arguments
# - Use a loop inside a function
# - Return a result that can be stored and reused
# - Write average and counting functions

# %% [markdown]
# ## Part 1: Repeating the Same Calculation
#
# The two lists below contain response times from two practice areas. Without a function, calculating both averages requires writing the same steps twice.

# %%
area_a_response_times = [5, 12, 7, 9, 15, 8]
area_b_response_times = [6, 10, 8, 11, 13, 7]

area_a_total = 0
for response_time in area_a_response_times:
    area_a_total = area_a_total + response_time
area_a_average = area_a_total / len(area_a_response_times)

area_b_total = 0
for response_time in area_b_response_times:
    area_b_total = area_b_total + response_time
area_b_average = area_b_total / len(area_b_response_times)

print(f"Area A average: {area_a_average:.1f} minutes")
print(f"Area B average: {area_b_average:.1f} minutes")

# %% [markdown]
# The two calculations follow the same instructions:
#
# 1. Start a total at zero.
# 2. Add every response time to the total.
# 3. Divide by the number of response times.
#
# A function lets us name those instructions once and use them with different lists.

# %% [markdown]
# ## Part 2: Define and Call a Function
#
# The function below accepts a list of response times, calculates the average, and returns the result.

# %%
def average_response_time(response_times):
    total = 0
    for response_time in response_times:
        total = total + response_time
    average = total / len(response_times)
    return average

# %%
area_a_average = average_response_time(area_a_response_times)
area_b_average = average_response_time(area_b_response_times)
difference = area_a_average - area_b_average

print(f"Area A average: {area_a_average:.1f} minutes")
print(f"Area B average: {area_b_average:.1f} minutes")
print(f"Difference: {difference:.1f} minutes")

# %% [markdown]
# ### Anatomy of the Function
#
# 1. `def` begins the function definition.
# 2. `average_response_time` is the function's name.
# 3. `response_times` is a parameter: the input name used inside the function.
# 4. The indented lines are the function body.
# 5. `return` sends the calculated value back to the line that called the function.
#
# Defining a function does not run it. The function runs when we call it with parentheses.

# %% [markdown]
# ## Part 3: Parameters and Arguments
#
# A **parameter** is an input name in the function definition. An **argument** is the actual value supplied when the function is called.
#
# The next function has two parameters. Changing either argument can change the result.

# %%
def response_status(response_minutes, threshold):
    if response_minutes > threshold:
        return "Over threshold"
    else:
        return "At or below threshold"

status_with_10_minute_threshold = response_status(12, 10)
status_with_15_minute_threshold = response_status(12, 15)

print(status_with_10_minute_threshold)
print(status_with_15_minute_threshold)

# %% [markdown]
# In `response_status(12, 10)`, `12` is the argument assigned to `response_minutes` and `10` is assigned to `threshold`. Argument order matters because Python matches the first argument to the first parameter, the second argument to the second parameter, and so on.

# %% [markdown]
# ## Part 4: `return` and `print` Are Different
#
# `print()` displays something. `return` sends a value out of the function so that the rest of the program can store it, compare it, or use it in another calculation.

# %%
def print_response_status(response_minutes, threshold):
    if response_minutes > threshold:
        print("Over threshold")
    else:
        print("At or below threshold")

printed_result = print_response_status(12, 10)
returned_result = response_status(12, 10)

print(f"Value from the print-only function: {printed_result}")
print(f"Value returned by response_status: {returned_result}")

# %% [markdown]
# The print-only function displays a message but gives back `None`. The function with `return` gives back a value that we can store in `returned_result` and use later.

# %% [markdown]
# ## Part 5: A Function That Counts Matches
#
# A function can combine parameters, a loop, a condition, a counter, and `return`.

# %%
def count_matches(values, target):
    count = 0
    for value in values:
        if value == target:
            count = count + 1
    return count

# %%
reported_incidents = [
    "theft", "assault", "theft", "burglary",
    "vandalism", "theft", "assault", "robbery"
]

theft_count = count_matches(reported_incidents, "theft")
assault_count = count_matches(reported_incidents, "assault")

print(f"Thefts: {theft_count}")
print(f"Assaults: {assault_count}")

# %% [markdown]
# ## What the Function Does—and What It Does Not Decide
#
# A function applies the rule we wrote consistently. It does not decide whether the input measures what we care about.
#
# For example, an average of daily 311 complaint counts describes recorded complaints. As the NYC 311 reading explains, complaint counts also reflect whether and how people report conditions. A correctly written function does not turn complaint counts into a direct measure of underlying noise.

# %% [markdown]
# ## Part 6: Common Function Errors
#
# ### Forgetting `return`
#
# The function below calculates a value but does not return it.

# %%
def add_two_numbers(first_number, second_number):
    result = first_number + second_number
    # No return statement

missing_result = add_two_numbers(4, 6)
print(missing_result)

# %% [markdown]
# ### Wrong Number of Arguments and Missing Parentheses
#
# The commented line would raise a `TypeError` because `response_status()` requires two arguments. Assigning the function without parentheses stores the function itself instead of calling it.

# %%
# response_status(12)  # TypeError: the threshold argument is missing

not_called = response_status
print(not_called)

called_correctly = response_status(12, 10)
print(called_correctly)

# %% [markdown]
# ## Hands-On Exercise: Average and Counting Functions
#
# Use the supplied practice data to complete each step.

# %%
practice_incidents = [
    "theft", "assault", "burglary", "theft", "robbery",
    "vandalism", "assault", "theft", "fraud", "assault"
]

practice_response_times = [5, 12, 7, 9, 15, 8, 11, 6, 14, 10]

# Step 1: Complete a function that calculates the average of a list.
# Use a loop to build the total. Do not use sum().
def calculate_average(values):
    total = 0
    # Your loop here
    # Return the average

# %%
# Step 2: Complete a reusable counting function.
def count_incident_type(incidents, target_type):
    count = 0
    # Your loop and condition here
    # Return the count

# %%
# Step 3: Call each function and store the returned results.
# Calculate the average response time.
# Count thefts.
# Count assaults.
# Print the three results.

# Your code here

# %%
# Step 4: Before running more code, make two predictions.
# 1. What will change if the target argument is changed from "theft" to "fraud"?
# 2. What will change if one response time is increased by 10 minutes?
#
# Test each prediction by modifying a function call or a copy of the data.

# Your code here

# %% [markdown]
# ## Challenge Exercise: Apply One Function to Two Groups
#
# Use your completed average function to:
#
# 1. Calculate the average for each list.
# 2. Subtract the Area D average from the Area C average.
# 3. Print both averages and the difference.
# 4. Explain what would change if you reversed the subtraction and calculated Area D minus Area C. Be precise about whether this affects the two averages, the difference, or both.

# %%
area_c_response_times = [8, 11, 7, 14, 10, 9]
area_d_response_times = [6, 8, 9, 10, 7, 8]

# Your code here

# %% [markdown]
# ## Reference: Additional Function Features
#
# The material below is useful but is not required for Problem Set 1.
#
# ### Keyword Arguments and a Zero Denominator
#
# Keyword arguments make the parameter names explicit. A function can also check for an input that would make its calculation impossible.

# %%
def calculate_rate(numerator, denominator):
    if denominator == 0:
        return None
    return (numerator / denominator) * 100

rate = calculate_rate(denominator=50, numerator=20)
print(rate)

# %% [markdown]
# ### Multiple Returned Values, Function Composition, and Docstrings
#
# A function can return more than one value and can call another function. A docstring records what the function does.

# %%
def summarize_response_times(values):
    """Return the minimum, maximum, and average response time."""
    fastest = min(values)
    slowest = max(values)
    average = average_response_time(values)
    return fastest, slowest, average

fastest, slowest, average = summarize_response_times(area_a_response_times)

print(f"Fastest: {fastest}")
print(f"Slowest: {slowest}")
print(f"Average: {average:.1f}")

# %% [markdown]
# Names created inside a function are local to that function. In the previous cell, the `average` created inside `summarize_response_times()` is separate from the `average` variable that receives the returned value outside the function.

# %% [markdown]
# ## Wrap-Up
#
# Today you learned:
#
# 1. `def` creates a function.
# 2. Parameters name the inputs a function expects.
# 3. Arguments are the values supplied when the function is called.
# 4. A function can use loops and conditions.
# 5. `return` sends a result back so it can be stored and reused.
# 6. The same function can be called with different inputs.
#
# Before Problem Set 1, be ready to:
#
# - Trace the accumulator in an average function one iteration at a time.
# - Explain why a counting function starts at zero.
# - Explain why the function returns a value instead of only printing it.
# - Predict what changes when an argument changes.
# - Make a small modification to a function.
#
# ### Function Template
#
# ```python
# def function_name(values, target):
#     result = 0
#     for value in values:
#         if value == target:
#             result = result + 1
#     return result
#
# stored_result = function_name(list_argument, target_argument)
# print(stored_result)
# ```
